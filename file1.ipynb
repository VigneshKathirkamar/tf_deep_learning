# %%
# importing the necessary libraries
import tensorflow as tf
import numpy as np

# %%
print(tf.__version__)
# Out:
# 2.6.2

# %%
# constructing a neural network with one neuron and 
# specifying the loss and optimizer function 
model = tf.keras.Sequential([tf.keras.layers.Dense(units=1,input_shape=[1])])
model.compile(optimizer='sgd',loss='mean_squared_error')

# %%
# data
x = np.array([-1,0,1,2,3,4],dtype=float)
y = np.array([1,2,3,4,5,6],dtype=float)

# %%
model.fit(x,y,epochs=500)
# Out:
# Epoch 1/500
# 1/1 [==============================] - 0s 168ms/step - loss: 37.8805
# Epoch 2/500
# 1/1 [==============================] - 0s 1ms/step - loss: 29.9645
# Epoch 3/500
# 1/1 [==============================] - 0s 1ms/step - loss: 23.7331
# Epoch 4/500
# 1/1 [==============================] - 0s 967us/step - loss: 18.8274
# Epoch 5/500
# 1/1 [==============================] - 0s 1ms/step - loss: 14.9646
# Epoch 6/500
# 1/1 [==============================] - 0s 1ms/step - loss: 11.9224
# Epoch 7/500
# 1/1 [==============================] - 0s 1ms/step - loss: 9.5258
# Epoch 8/500
# 1/1 [==============================] - 0s 1ms/step - loss: 7.6374
# Epoch 9/500
# 1/1 [==============================] - 0s 1ms/step - loss: 6.1487
# Epoch 10/500
# 1/1 [==============================] - 0s 2ms/step - loss: 4.9746
# Epoch 11/500
# 1/1 [==============================] - 0s 2ms/step - loss: 4.0481
# Epoch 12/500
# 1/1 [==============================] - 0s 2ms/step - loss: 3.3164
# ...

# %%
model.predict([10])
# Out:
# array([[12.015079]], dtype=float32)

# %% [markdown]
# # Trying on cubic equation

# %%
# importing the necessary libraries
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# %%
# constructing a neural network with one neuron and 
# specifying the loss and optimizer function 
model = tf.keras.Sequential([tf.keras.layers.Dense(units=1,input_shape=[1]),
                            tf.keras.layers.Dense(units=10,activation='relu'),
                            tf.keras.layers.Dense(units=10,activation='relu'),
                            tf.keras.layers.Dense(units=1)])
model.compile(optimizer='sgd',loss='mean_squared_logarithmic_error', metrics=['accuracy'])

# %%
# data
x = np.array([-1,0,1,2,3,4],dtype=float)
y = x**3 + x**2 + x + 10

# %%
history = model.fit(x,y,epochs=500)

# %%
print(history.history.keys())
# loss_train = history.history['loss']
# #loss_val = history.history['val_loss']
# epochs = range(0,5000)
# plt.plot(epochs, loss_train, 'g', label='Training loss')
# #plt.plot(epochs, loss_val, 'b', label='validation loss')
# plt.title('Training and Validation loss')
# plt.xlabel('Epochs')
# plt.ylabel('Loss')
# plt.legend()
# plt.show()

# %%
# importing the necessary libraries
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# %%
# constructing a neural network with one neuron and 
# specifying the loss and optimizer function 
model = tf.keras.Sequential([tf.keras.layers.Dense(units=1,input_shape=[1]),
                            tf.keras.layers.Dense(units=10),
                            tf.keras.layers.Dense(units=1)])
model.compile(optimizer='sgd',loss='mean_squared_logarithmic_error',metrics=['accuracy'])

# %%
# data
x = np.array([-1,0,1,2,3,4],dtype=float)
y = x**3 + x**2 + x + 10

# %%
history = model.fit(x,y,epochs=500)
# Out:
# Epoch 1/500
# 1/1 [==============================] - 0s 183ms/step - loss: 10.1250 - accuracy: 0.0000e+00
# Epoch 2/500
# 1/1 [==============================] - 0s 2ms/step - loss: 10.1145 - accuracy: 0.0000e+00
# Epoch 3/500
# 1/1 [==============================] - 0s 2ms/step - loss: 10.0620 - accuracy: 0.0000e+00
# Epoch 4/500
# 1/1 [==============================] - 0s 2ms/step - loss: 10.0158 - accuracy: 0.0000e+00
# Epoch 5/500
# 1/1 [==============================] - 0s 1ms/step - loss: 9.9744 - accuracy: 0.0000e+00
# Epoch 6/500
# 1/1 [==============================] - 0s 2ms/step - loss: 9.9370 - accuracy: 0.0000e+00
# Epoch 7/500
# 1/1 [==============================] - 0s 2ms/step - loss: 9.9028 - accuracy: 0.0000e+00
# Epoch 8/500
# 1/1 [==============================] - 0s 1ms/step - loss: 9.8715 - accuracy: 0.0000e+00
# Epoch 9/500
# 1/1 [==============================] - 0s 2ms/step - loss: 9.8424 - accuracy: 0.0000e+00
# Epoch 10/500
# ...

# %%
#print(history.history.keys())
loss_train = history.history['loss']
#loss_val = history.history['val_loss']
epochs = range(0,500)
plt.plot(epochs, loss_train, 'g', label='Training loss')
# plt.plot(epochs, loss_val, 'b', label='validation loss')
plt.title('Training and Validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
